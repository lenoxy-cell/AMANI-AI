# %% [markdown]
# <a href="https://colab.research.google.com/github/lenoxy-cell/AMANI-AI/blob/main/business_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BusinessAI:

    def greet(self):
        print("Welcome to Business AI")
