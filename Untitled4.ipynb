# %% [markdown]
# <a href="https://colab.research.google.com/github/lenoxy-cell/AMANI-AI/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("what's your name?")
age=input("how old are you")
food=input("what's your favourite food?")
print("\n welcome",name)
# Out:
# what's your name?kenny
# how old are you19
# what's your favourite food?chips
#
#  welcome kenny
