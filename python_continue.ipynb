# %% [markdown]
# <a href="https://colab.research.google.com/github/lenoxy-cell/AMANI-AI/blob/main/python_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cccc
# Out:
# Agriculture AI
# Education AI
# 4
# Agriculture AI
# Business AI
# Data Analysis AI
# Education AI

# %%
ai_assistants = ["Agriculture AI","Business AI","Data Analysis AI","Education AI"]
print(ai_assistants[0])
print(ai_assistants[-1])
print(len(ai_assistants))
for ai_assistant in ai_assistants :
  print(ai_assistant)
# Out:
# Agriculture AI
# Education AI
# 4
# Agriculture AI
# Business AI
# Data Analysis AI
# Education AI

# %%
student = {
    "name": "Kennedy",
    "age": 22,
    "country": "Rwanda",
    "course": "Python"
}
print(student["name"])
print(student["age"])
print(student["country"])
print(student["course"])
student["age"]=23
print(student["age"])
# Out:
# Kennedy
# 22
# Rwanda
# Python
# 23

# %%
assistant= {
    "name" : " Business AI",
    "Version" : "1.0",
    "Developer" : "Kennedy Dusengimana",
    "Status" : "Active"
}
print(assistant["name"])
print(assistant["Developer"])
print(assistant["Status"])
assistant["version"] = 2.0
print(assistant["version"])
# Out:
#  Business AI
# Kennedy Dusengimana
# Active

# %%
ai_assistants = [
    {
        "name": "Agriculture AI",
        "version": "1.0",
        "status": "Active"
    },
    {
        "name": "Business AI",
        "version": "1.2",
        "status": "Active"
    }
]
for ai_assistant in ai_assistants :
  print(f"{ai_assistant["name"]} - {ai_assistant["version"]} - {ai_assistant["status"]} ")
# Out:
# Agriculture AI - 1.0 - Active
# Business AI - 1.2 - Active

# %%
ai_assistants = [

    {

        "name": "Agriculture AI",

        "version": "1.0",

        "status": "Active"

    },

    {

        "name": "Business AI",

        "version": "1.2",

        "status": "Active"

    }

]

for i, assistant_item in enumerate(ai_assistants):

  print(f"{i+1}.{assistant_item}")

choice = int(input("choose an assistant you wish in those:"))



# Validate the choice to prevent IndexError and correctly access the list

if 1 <= choice <= len(ai_assistants):

    selected = ai_assistants[choice - 1] # Correctly access from the list of assistants

    print(f"Name: {selected['name']}")

    print(f"Version: {selected['version']}")

    print(f"Status: {selected['status']}")

else:

    print("Invalid choice. Please select a number within the given range.")
# Out:
# 1.{'name': 'Agriculture AI', 'version': '1.0', 'status': 'Active'}
# 2.{'name': 'Business AI', 'version': '1.2', 'status': 'Active'}
# choose an assistant you wish in those:2
# Name: Business AI
# Version: 1.2
# Status: Active

# %%
class AIAssistant:
    def __init__(self, name, version, status):
        self.name = name
        self.version = version
        self.status = status
business_ai = AIAssistant("Business AI", "1.2", "Active")
print(business_ai.name)
print(business_ai.version)
print(business_ai.status)
# Out:
# Business AI
# 1.2
# Active

# %%
class Student :
  def __init__(self,name,age,course) :
    self.name = name
    self.age = age # Corrected from self.version = version
    self.course = course
Ultra_rich=Student("Kennedy",22,"Python")
Boss_lady=Student("Alice",20,"Data Science")
print(f"{Ultra_rich.name},{Ultra_rich.age},{Ultra_rich.course}")
print(f"{Boss_lady.name},{Boss_lady.age},{Boss_lady.course}") # Corrected Boss_lady,name to Boss_lady.name
# Out:
# Kennedy,22,Python
# Alice,20,Data Science

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course

    def introduce(self):
        print(f"Hello! My name is {self.name}.")
        print(f"I am {self.age} years old.")
        print(f"I am studying {self.course}.")
student1 = Student("Kennedy", 22, "Python")
student1.introduce()
# Out:
# Hello! My name is Kennedy.
# I am 22 years old.
# I am studying Python.

# %%
class AIAssistant:
  def __init__(self, name, version, status):
    self.name = name
    self.version = version
    self.status = status

  def display_info(self):
    print(f"Assistant : {self.name}")
    print(f"Version : {self.version}")
    print(f"Status : {self.status}")

info = AIAssistant("Business AI","2.0","Active")
info.display_info()
# Out:
# Assistant : Business AI
# Version : 2.0
# Status : Active

# %%
class AIAssistant:
    def __init__(self, name, version):
        self.name = name
        self.version = version

    def display(self):
        print(f"{self.name} - Version {self.version}")
class AgricultureAI(AIAssistant):
    pass
agri = AgricultureAI("Agriculture AI", "1.0")
agri.display()
# Out:
# Agriculture AI - Version 1.0

# %%
class Animal :
  def __init__(self,name,sound) :
    self.name = name
    self.sound = sound

  def speak(self) :
    print(f"{self.name} is {self.sound}")
class Dog(Animal) :
  pass
m=Dog("Dog","barking")
m.speak()
# Out:
# Dog is barking

# %%
class Animal:
    def speak(self):
        print("This animal makes a sound.")
class Dog(Animal):
    def speak(self):
        print("Woof! Woof!")

class Cat(Animal):
    def speak(self):
        print("Meow!")

class Bird(Animal):
    def speak(self):
        print("Tweet!")
animals = [
    Dog(),
    Cat(),
    Bird()
]

for animal in animals:
    animal.speak()
# Out:
# Woof! Woof!
# Meow!
# Tweet!

# %%
class Employee :
    def work(self):
      print("Employee is working")
class Programmer(Employee) :
    def work(self) :
      print("Programmer is writing codes")
class Designer(Employee) :
    def work(self) :
      print("Designer is creating  designs")
employees = [
    Programmer(),
    Designer()
]
for employee in employees :
      employee.work()
# Out:
# Programmer is writing codes
# Designer is creating  designs

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def move(self):
        pass
class Car(Vehicle):
    def move(self):
        print("The car drives on the road.")

class Plane(Vehicle):
    def move(self):
        print("The plane flies in the sky.")

# %%
from abc import ABC ,abstractmethod
class Payment(ABC) :
  @abstractmethod
  def pay(self) :
    pass
class CreditCard(Payment) :
  def pay(self):
    print("Payment made using Credit Card")

class Paypal(Payment) :
  def pay(self):
    print("Payment made using Paypal")

# %% [markdown]
# #python import
