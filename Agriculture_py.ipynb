# %% [markdown]
# <a href="https://colab.research.google.com/github/lenoxy-cell/AMANI-AI/blob/main/Agriculture_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class AgricultureAI:

    def greet(self):
        print("Welcome to Agriculture AI")
